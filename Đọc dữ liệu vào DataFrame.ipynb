# %%
import pandas as pd

df = pd.read_csv("/Users/mac/Desktop/DA2212R1/FoodPrice_in_Turkey.csv", encoding = "UTF-8")
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
import pandas as pd
file = "/Users/mac/Desktop/DA2212R1/FoodPrice_in_Turkey.csv"
df = pd.read_csv(file, encoding = "UTF-8")
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
# Cách 1: Ghi tường minh các tham số
import pandas as pd
df=pd.read_csv(filepath_or_buffer = 'FoodPrice_in_Turkey.csv', sep = ',')
# Hiển thị 5 dòng dữ liệu đầu tiên
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df.to_excel("FoodPrice_in_Turkey.xlsx")

# %%
df=pd.read_excel("FoodPrice_in_Turkey.xlsx")
df.head()
# Out:
#    Unnamed: 0             Place  ProductId    ProductName  UmId UmName  Month  \
# 0           0  National Average         52  Rice - Retail     5     KG      5
# 1           1  National Average         52  Rice - Retail     5     KG      6
# 2           2  National Average         52  Rice - Retail     5     KG     11
# 3           3  National Average         52  Rice - Retail     5     KG     12
# 4           4  National Average         52  Rice - Retail     5     KG      1
#
#    Year   Price
# 0  2013  4.4920
# 1  2013  4.5786
# 2  2013  4.7865
# 3  2013  5.1337
# 4  2014  5.5099

# %%
df.to_json("FoodPrice_in_Turkey.json",orient = "columns")

# %%
df = pd.read_json("FoodPrice_in_Turkey.json")
df.head()
# Out:
#    Unnamed: 0             Place  ProductId    ProductName  UmId UmName  Month  \
# 0           0  National Average         52  Rice - Retail     5     KG      5
# 1           1  National Average         52  Rice - Retail     5     KG      6
# 2           2  National Average         52  Rice - Retail     5     KG     11
# 3           3  National Average         52  Rice - Retail     5     KG     12
# 4           4  National Average         52  Rice - Retail     5     KG      1
#
#    Year   Price
# 0  2013  4.4920
# 1  2013  4.5786
# 2  2013  4.7865
# 3  2013  5.1337
# 4  2014  5.5099

# %%
df.to_hdf("FoodPrice_in_Turkey.h5","table")

# %%
df=pd.read_hdf("FoodPrice_in_Turkey.h5", "table")
df.head()
# Out:
#    Unnamed: 0             Place  ProductId    ProductName  UmId UmName  Month  \
# 0           0  National Average         52  Rice - Retail     5     KG      5
# 1           1  National Average         52  Rice - Retail     5     KG      6
# 2           2  National Average         52  Rice - Retail     5     KG     11
# 3           3  National Average         52  Rice - Retail     5     KG     12
# 4           4  National Average         52  Rice - Retail     5     KG      1
#
#    Year   Price
# 0  2013  4.4920
# 1  2013  4.5786
# 2  2013  4.7865
# 3  2013  5.1337
# 4  2014  5.5099

# %%
url = 'https://en.wikipedia.org/wiki/List_of_sovereign_states_and_dependent_territories_in_North_America'
df = pd.read_html(url)
df[0].head()
# Out:
#    Flag  Map  English short, formal names, and ISO [1][2][3][4]  \
# 0   NaN  NaN                       Antigua and Barbuda[n 1] ATG
# 1   NaN  NaN  Bahamas, The[n 1] Commonwealth of The Bahamas BHS
# 2   NaN  NaN                                  Barbados[n 1] BRB
# 3   NaN  NaN                               Belize[n 1][n 2] BLZ
# 4   NaN  NaN                                    Canada[n 3] CAN
#
#            Domestic short and formal name(s) [1][2] Capital [3][5][6]  \
# 0                      English: Antigua and Barbuda        St. John's
# 1  English: The Bahamas—Commonwealth of The Bahamas            Nassau
# 2                                 English: Barbados        Bridgetown
# 3                                   English: Belize          Belmopan
# 4                    English: Canada French: Canada            Ottawa
#
#    Population 2021 [7][8]                         Area [9]  \
# 0                   93219            442.6 km2 (171 sq mi)
# ...
