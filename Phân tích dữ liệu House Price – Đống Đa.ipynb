# %%
import pandas as pd
import numpy as np

df = pd.read_csv("house_price_Dống-Da_Hà-Nội_subdata.csv")
df
# Out:
#       area    price  postDate land_certificate house_direction  \
# 0     50.0  14700.0     44197            So do             NaN
# 1     57.0   4200.0     44265            So do             Nam
# 2     62.0  11000.0     44268            So do             NaN
# 3     26.0   2900.0     44292            So do             NaN
# 4     40.0   3950.0     44292            So do             NaN
# ..     ...      ...       ...              ...             ...
# 666  168.0  23500.0     44325              NaN             NaN
# 667   65.0  17500.0     44325            So do             NaN
# 668   60.0  17500.0     44197              NaN             NaN
# 669   45.0  24800.0     44197              NaN             NaN
# 670  107.0  45000.0     44325            So do             NaN
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 0                 NaN     4.0      6.0    6.0  21.015698  105.824583
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   area               665 non-null    float64
#  1   price              617 non-null    float64
#  2   postDate           671 non-null    int64
#  3   land_certificate   369 non-null    object
#  4   house_direction    42 non-null     object
#  5   balcony_direction  24 non-null     object
#  6   toilet             240 non-null    float64
#  7   bedroom            320 non-null    float64
#  8   floor              366 non-null    float64
#  9   lat                671 non-null    float64
#  10  long               671 non-null    float64
#  11  property_type      671 non-null    object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 63.0+ KB

# %%
df["lat"].unique()
# Out:
# array([21.0156983, 21.025208 , 21.0253793, 21.0143249, 21.0098623,
#        21.0123103, 21.0216521, 21.0190779, 21.0225776, 21.0170062,
#        21.0210979, 21.0067122, 21.0080687, 21.0235829, 20.9984988,
#        21.0157955, 21.0051976, 21.0075479, 21.0289054, 21.0203116,
#        21.0044301, 21.0047296, 21.0156395, 21.0066938, 21.0104478,
#        21.0012748, 21.0129876, 21.011875 , 21.0253784, 21.0097394,
#        21.0268209, 21.026246 , 21.0084004, 21.0151077, 21.0240516,
#        21.0217916, 21.0239665, 21.0022945, 21.0189953, 21.0180725,
#        21.0089298, 21.0172878, 21.0190982, 21.004538 , 21.0167222,
#        21.0278358, 21.013056 , 21.012183 , 21.0092389, 21.0295218,
#        21.0195075, 21.0194469, 21.0240383, 21.0202589, 21.0053431,
#        21.0057491, 21.0058865, 21.0248712, 21.0094101, 21.0128724,
#        21.0191836, 21.0128979, 21.019454 , 21.0185208, 21.0164931,
#        21.0114953, 21.001965 , 21.0146124, 21.0005493, 21.0201687,
# ...

# %%
df1 = df[((df["land_certificate"]=="So do")&((df["lat"]==21.0108448)|(df["lat"]==21.0195075)))][0:670]
df1
# Out:
#      area    price  postDate land_certificate house_direction  \
# 203  50.0  13500.0     44292            So do             NaN
# 281  71.0  15500.0     44312            So do             NaN
# 551  40.0  18500.0     44312            So do             NaN
#
#     balcony_direction  toilet  bedroom  floor        lat        long  \
# 203               NaN     NaN      7.0    5.0  21.019507  105.805769
# 281               NaN     5.0      8.0    6.0  21.019507  105.805769
# 551               NaN     4.0      4.0    5.0  21.010845  105.822425
#
#     property_type
# 203     trong ngo
# 281     trong ngo
# 551       mat pho

# %%
df2 = df[((df["land_certificate"]== "So do")&(df["bedroom"]>=3))].filter(['area','price','house_direction','balcony_direction'])
df2
# Out:
#       area    price house_direction balcony_direction
# 0     50.0  14700.0             NaN               NaN
# 1     57.0   4200.0             Nam               Nam
# 2     62.0  11000.0             NaN          dong-Nam
# 3     26.0   2900.0             NaN               NaN
# 6     39.0   5280.0         Tay-Nam               NaN
# ..     ...      ...             ...               ...
# 650  100.0  22500.0             NaN               NaN
# 653   45.0  30000.0        dong-Bac               NaN
# 659   45.0  12000.0        dong-Nam               NaN
# 663  143.0  72000.0             NaN               NaN
# 667   65.0  17500.0             NaN               NaN
#
# [206 rows x 4 columns]

# %%
df3 = df.groupby(['land_certificate'])[['price']].mean()
df3
# Out:
#                         price
# land_certificate
# So do             20226.53649
